# %% [markdown]
# # Real Data

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
# %load_ext rmagic
# Out:
# The rmagic extension is already loaded. To reload it, use:
#   %reload_ext rmagic

# %% [markdown]
# #### Load

# %%
# %%R
# Xest<-data.matrix(read.table('Real_Xest.txt',sep=','))
# Yest<-data.matrix(read.table('Real_Yest.txt',sep=',')) # is slow to read these in
# Xval<-data.matrix(read.table('Real_Xval.txt',sep=','))
# Yval<-data.matrix(read.table('Real_Yval.txt',sep=','))
# voxIdx<-data.matrix(read.table('Real_voxIdx.txt',sep=','))

# %%
# %%R
# t(Xest)%*%Xest
# Out:
#                 V1            V2            V3           V4            V5
# V1    4103.9973740 -1023.4484603  -820.5483034   524.092741  4.827444e+02
# V2   -1023.4484603  4103.9817656 -2753.0378209     9.503640 -2.409089e+01
# V3    -820.5483034 -2753.0378209  4103.9832386  -220.411255 -9.669312e+01
# V4     524.0927410     9.5036401  -220.4112553  4104.024537  4.222325e+01
# V5     482.7444355   -24.0908937   -96.6931179    42.223249  4.103992e+03
# V6    -932.6945259  3244.3199651 -3478.1984125    94.121449 -1.329749e+02
# V7    1045.4593924 -2158.7664654  1283.5230369   306.445934 -1.378520e+02
# V8     -97.8389462   179.8259938   -30.1954523   -97.597103  3.617399e+01
# V9    -173.2065249  -101.2873645   495.3913120   130.735006  1.155410e+02
# V10    882.4534041  -665.3256322   724.8048207  -100.558986  1.186393e+03
# V11   1091.8514281 -1726.6683403   999.6504097   422.267016 -1.749309e+02
# V12    -53.8752639    68.0349743  -126.8724173   762.081200 -2.173935e+02
# ...
